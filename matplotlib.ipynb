# %%
# !pip install matplotlib
from matplotlib import pyplot as plt
# !pip install seaborn

# %%
x = [7,10,11]
y = [12,16,14]
plt.plot(x,y)
plt.title('student marks')
plt.ylabel('sample data')
plt.xlabel('sample data')
plt.show()

# %%
import numpy as np

# %%
xpoints = np.array([15,4,3])
ypoints = np.array([16,2,5])
plt.plot(xpoints, ypoints, 'o')
plt.title('ploting without line')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.show()

# %%
x = np.array([80,85,90,95,100,105,110,115,120,125])
y = np.array([240,250,260,270,280,290,300,310,320,330])
plt.title("sports watch data")
plt.xlabel("average pulse")
plt.ylabel("calories burnage")
plt.plot(x,y)
plt.grid()
plt.show()

# %%
ypoints = np.array([3,8,10,9])
xpoints = np.array([13,18,11,10])
plt.plot(xpoints, ypoints, marker = 'd')
plt.show()

# %%
plt.plot(ypoints, marker = '*', ms = 30, mec = 'g', mfc = 'r')

# %%
ypoints = np.array([3,8,1,10])
plt.plot(ypoints,linestyle = 'dotted')
plt.show()

# %%
plt.plot(ypoints, linewidth = '7', color = 'y')
plt.show()

# %%
# plot1:
x = np.array([0,1,2,3])
y = np.array([3,8,1,10])
print(x)
print(y)
plt.subplot(1,2,1)
plt.plot(x,y)
# plot2:
x = np.array([0,1,2,3])
y = np.array([10,20,30,40])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.show()
# Out:
# [0 1 2 3]
# [ 3  8  1 10]

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([0,1,2,3])
y = np.array([3,8,1,10])
plt.subplot(2,3,1)
plt.plot(x,y)

x = np.array([0,1,2,3])
y = np.array([10,20,30,40])
plt.subplot(2,3,2)
plt.plot(x,y)

x = np.array([0,1,2,3])
y = np.array([3,8,1,10])
plt.subplot(2,3,3)
plt.plot(x,y)

x = np.array([0,1,2,3])
y = np.array([10,20,30,40])
plt.subplot(2,3,5)
plt.plot(x,y)

x = np.array([0,1,2,3])
y = np.array([3,8,1,10])
plt.subplot(2,3,6)
plt.plot(x,y)
plt.show()
