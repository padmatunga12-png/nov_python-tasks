# %%
# !pip install pandas
# !pip install numpy
import pandas as pd
import numpy as np

# %%
# Series
s1 = pd.Series([23,24,25,12,'32'])
s1
# Out:
# 0    23
# 1    24
# 2    25
# 3    12
# 4    32
# dtype: object

# %%
s2 = pd.Series([24,45,67,12,34], index = ['suman', 'charan', 'vinith', 'kushal', 'koushik'])
s2
# Out:
# suman      24
# charan     45
# vinith     67
# kushal     12
# koushik    34
# dtype: int64

# %%
s3 = pd.Series([23,45,67,12,34], index = ['kusuma', 'likitha', 'nikitha', 'bhanu', 'renuka'], dtype = 'float')
s3
# Out:
# kusuma     23.0
# likitha    45.0
# nikitha    67.0
# bhanu      12.0
# renuka     34.0
# dtype: float64

# %%
# Series in dictionaries
s4 = pd.Series({'apple':65, 'banana':43, 'mangoes':45})
s4
# Out:
# apple      65
# banana     43
# mangoes    45
# dtype: int64

# %%
# DataFrame
d1 = pd.DataFrame([43,54,65,76])
d1
# Out:
#     0
# 0  43
# 1  54
# 2  65
# 3  76

# %%
d2 = pd.DataFrame([[200,300,400],
                  [401,500,600],
                  [100,201,301]])
d2
# Out:
#      0    1    2
# 0  200  300  400
# 1  401  500  600
# 2  100  201  301
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# d2[0].plot(kind='hist', bins=20, title=0)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# d2[1].plot(kind='hist', bins=20, title=1)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# d2[2].plot(kind='hist', bins=20, title=2)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# d2.plot(kind='scatter', x=0, y=1, s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
# Series into DataFrames
d2 = pd.DataFrame(s2)
d2
# Out:
#           0
# suman    24
# charan   45
# vinith   67
# kushal   12
# koushik  34

# %%
# changing column names
d3 = pd.DataFrame([[2, 3, 4], [4, 5, 6], [1, 2, 3]], columns = ['emp_id', 'stu_id', 'workers'])
d3
# Out:
#    emp_id  stu_id  workers
# 0       2       3        4
# 1       4       5        6
# 2       1       2        3

# %%
# changing index positions
d3 = pd.DataFrame([[2,3,4], [4,5,6], [1,2,3]], columns = ['emp_id', 'stu_id','workers'], index = ['krithik', 'koushal', 'karthik'])
d3
# Out:
#          emp_id  stu_id  workers
# krithik       2       3        4
# koushal       4       5        6
# karthik       1       2        3

# %%
# creatin DataFrame from list of dictionaries
dic = [{'rice':21, 'dal':20}, {'potato':15, 'onion':30, 'carrot':15}, {'dal':20, 'beans':14, 'carrot':16}]
pd.DataFrame(dic,index = ['abc','cde','efg'])
# Out:
#      rice   dal  potato  onion  carrot  beans
# abc  21.0  20.0     NaN    NaN     NaN    NaN
# cde   NaN   NaN    15.0   30.0    15.0    NaN
# efg   NaN  20.0     NaN    NaN    16.0   14.0

# %%
# DataFrame operations (accessing column data)
print(d3['emp_id'])
print(d3['stu_id'])
# Out:
# krithik    2
# koushal    4
# karthik    1
# Name: emp_id, dtype: int64
# krithik    3
# koushal    5
# karthik    2
# Name: stu_id, dtype: int64

# %%
d3 = pd.DataFrame([[2,3,4], [4,5,6], [1,2,3]], columns = ['a','b','c'])
d3
# Out:
#    a  b  c
# 0  2  3  4
# 1  4  5  6
# 2  1  2  3

# %%
# column wise operation
d3['d'] = d3['a']*d3['b']
d3['e'] = d3['a']+d3['d']
d3
# Out:
#    a  b  c   d   e
# 0  2  3  4   6   8
# 1  4  5  6  20  24
# 2  1  2  3   2   3

# %%
# pop
pop = d3.pop('b')
d3
# Out:
#    a  c   d   e
# 0  2  4   6   8
# 1  4  6  20  24
# 2  1  3   2   3

# %%
# delete
del d3['d']
d3
# Out:
#    a  c   e
# 0  2  4   8
# 1  4  6  24
# 2  1  3   3

# %%
# inserting
d3.insert(1,'new1',d3['c'])
d3
# Out:
#    a  new1  c   e
# 0  2     4  4   8
# 1  4     6  6  24
# 2  1     3  3   3

# %%
# append
d = {'c':1, 'new1':33, 'e':22}
df11 = d3._append(d,ignore_index = True)
df11
# Out:
#      a  new1  c   e
# 0  2.0     4  4   8
# 1  4.0     6  6  24
# 2  1.0     3  3   3
# 3  NaN    33  1  22

# %%
# head
d2.head()
# Out:
#           0
# suman    24
# charan   45
# vinith   67
# kushal   12
# koushik  34

# %%
# tail
d3.tail()
# Out:
#    a  new1  c   e
# 0  2     4  4   8
# 1  4     6  6  24
# 2  1     3  3   3

# %%
# info , describe
d2.info()
d2.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, suman to koushik
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       5 non-null      int64
# dtypes: int64(1)
# memory usage: 252.0+ bytes
#                0
# count   5.000000
# mean   36.400000
# std    21.007142
# min    12.000000
# 25%    24.000000
# 50%    34.000000
# 75%    45.000000
# max    67.000000

# %%
d4 = pd.DataFrame({'abc': [1,2,3], 'cde': [4,5,6], 'efg': [7,8,9]})
d4
# Out:
#    abc  cde  efg
# 0    1    4    7
# 1    2    5    8
# 2    3    6    9

# %%
# location
print(d4.loc[1,'abc'])
# Out:
# 2

# %%
# slicing
d4.loc[2:9, ['abc', 'cde']]
# Out:
#    abc  cde
# 2    3    6

# %%
# iloc
print(d4.iloc[1,2])
# Out:
# 8

# %%
# iloc slicing
d4.iloc[2:7,[0,2]]
# Out:
#    abc  efg
# 2    3    9

# %%
d4.abc
# Out:
# 0    1
# 1    2
# 2    3
# Name: abc, dtype: int64

# %%
d4.abc.values
# Out:
# array([1, 2, 3])

# %%
d4['sub'] = d4.abc.values-d4.cde.values-d4.efg.values
d4
# Out:
#    abc  cde  efg  sub
# 0    1    4    7  -10
# 1    2    5    8  -11
# 2    3    6    9  -12

# %%
a = [['rk', 102, 15000], ['rama', 103, 20000], ['krishna', 104, 25000]]
df1 = pd.DataFrame(a,columns = ['name', 'id', 'salary'])
df1
# Out:
#       name   id  salary
# 0       rk  102   15000
# 1     rama  103   20000
# 2  krishna  104   25000

# %%
y = df1[df1.salary>=20000]
print(y)
y[['id', 'salary']]
# Out:
#       name   id  salary
# 1     rama  103   20000
# 2  krishna  104   25000
#     id  salary
# 1  103   20000
# 2  104   25000

# %%
# append
df1._append({'name': 'aravind', 'id': 105, 'salary': 30000}, ignore_index=True)
# Out:
#       name   id  salary
# 0       rk  102   15000
# 1     rama  103   20000
# 2  krishna  104   25000
# 3  aravind  105   30000

# %%
# nan
df1 = df1._append({'name': np.nan, 'id': 105, 'salary': 30000}, ignore_index=True)
df1
# Out:
#       name     id   salary
# 0       rk  102.0  15000.0
# 1     rama  103.0  20000.0
# 2  krishna  104.0  25000.0
# 3      NaN  105.0  30000.0
# 4      NaN  105.0  30000.0

# %%
# isnull()
df1.isnull()
# Out:
#     name     id  salary
# 0  False  False   False
# 1  False  False   False
# 2  False  False   False
# 3   True  False   False
# 4   True  False   False

# %%
# info()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   id      5 non-null      float64
#  2   salary  5 non-null      float64
# dtypes: float64(2), object(1)
# memory usage: 252.0+ bytes

# %%
# dropna()
df1.dropna()
# Out:
#       name     id   salary
# 0       rk  102.0  15000.0
# 1     rama  103.0  20000.0
# 2  krishna  104.0  25000.0

# %%
# fillna()
df1.fillna(value = 'abc')
# Out:
#       name     id   salary
# 0       rk  102.0  15000.0
# 1     rama  103.0  20000.0
# 2  krishna  104.0  25000.0
# 3      abc  105.0  30000.0
# 4      abc  105.0  30000.0

# %%
# drop()
df1.drop([2], axis = 0, inplace=True)
df1
# Out:
#    name     id   salary
# 0    rk  102.0  15000.0
# 1  rama  103.0  20000.0
# 3   NaN  105.0  30000.0
# 4   NaN  105.0  30000.0

# %%
# groupby
import pandas as pd
df = pd.DataFrame({'animal': ['falcon', 'falcon', 'parrot', 'parrot'], 'maxspeed': [380.,370.,24.,26], 'wind speed': [380.,370.,24.,26.]})
df
# Out:
#    animal  maxspeed  wind speed
# 0  falcon     380.0       380.0
# 1  falcon     370.0       370.0
# 2  parrot      24.0        24.0
# 3  parrot      26.0        26.0

# %%
df.groupby(['animal']).mean()
# Out:
#         maxspeed  wind speed
# animal
# falcon     375.0       375.0
# parrot      25.0        25.0

# %%
# transpose
df.T
# Out:
#                  0       1       2       3
# animal      falcon  falcon  parrot  parrot
# maxspeed     380.0   370.0    24.0    26.0
# wind speed   380.0   370.0    24.0    26.0

# %%
# using numpy
import numpy as np
d4 = pd.DataFrame({ 'abc': np.random.randint(2,6, size = (10)), 'bcd': np.random.randint(4,10, size = (10)), 'cde': np.random.randint(3,10, size = (10))})
d4
# Out:
#    abc  bcd  cde
# 0    5    6    5
# 1    4    4    4
# 2    3    7    6
# 3    2    8    5
# 4    4    5    8
# 5    3    6    9
# 6    5    8    4
# 7    3    6    9
# 8    5    8    4
# 9    4    7    6
